# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
import os 
uncleaned = pd.ExcelFile("Weatherdata1996to2020.xls")
data_path = "C:\\Users\\Nakesh\\Desktop\\weather data\\jupyter-notebook-weather-project\\date wise csv"

# %%
# looping to all the csv file to make a single csv file
all_data = []
for year in range(1996 , 2021):
    if year in [2006,2007]:
        continue
    file_name = f"{year}.csv"
    file_path = os.path.join(data_path , file_name)
    df = pd.read_csv(file_path)
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df = df[~df['Date'].astype(str).str.contains("Average", na=False)]
    df['Year'] = year
    all_data.append(df)

# %%
merged_df = pd.concat(all_data , ignore_index=True)
merged_df.to_csv("combined_weather_data.csv" , index = False)
# merged_df.head(30)
# merged_df.tail(30)

# %%
weather = pd.read_csv("combined_weather_data.csv")
# weather.iloc[ 500 : 530]

# %% [markdown]
# ### Analysis Before data Cleaning ###

# %%
sheet_names = uncleaned.sheet_names

# %%
# describe the basics maths funcitons like mean median & mode  etc .
# Loop through each sheet

for sheet in sheet_names:
    df = pd.read_excel("Weatherdata1996to2020.xls", sheet_name=sheet)
    print(f"\nSheet: {sheet}")
    print("-" * 40)

    # Try to convert all columns to numeric (coerce errors)
    df_numeric = df.apply(pd.to_numeric, errors='coerce')

    # Select only numeric columns (jo ab ban gaye hain)
    numeric_df = df_numeric.select_dtypes(include='number')

    if numeric_df.empty:
        print("No numeric columns found after conversion.")
        continue

    print("Mean:")
    print(numeric_df.mean())

    print("Median:")
    print(numeric_df.median())

    print("Mode:")
    print(numeric_df.mode().iloc[0])
# Out:
# Sheet: 1996
# ----------------------------------------
# Mean:
# Year 1996           NaN
# Unnamed: 1    31.739071
# Unnamed: 2    19.675956
# Unnamed: 3    62.383880
# Unnamed: 4    41.655191
# Unnamed: 5     1.811202
# Unnamed: 6     5.902077
# dtype: float64
# Median:
# Year 1996       NaN
# Unnamed: 1    30.00
# Unnamed: 2    21.00
# Unnamed: 3    60.00
# Unnamed: 4    35.50
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Year 1996       NaN
# Unnamed: 1    28.00
# Unnamed: 2    25.00
# Unnamed: 3    84.00
# Unnamed: 4    22.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# Name: 0, dtype: float64
#
# Sheet: 1997
# ----------------------------------------
# Mean:
# Year 1997           NaN
# Unnamed: 1    29.000000
# Unnamed: 2    19.668493
# Unnamed: 3    73.580822
# Unnamed: 4    54.726575
# Unnamed: 5     2.568767
# Unnamed: 6     5.548027
# dtype: float64
# Median:
# Year 1997       NaN
# Unnamed: 1    29.00
# Unnamed: 2    21.60
# Unnamed: 3    76.00
# Unnamed: 4    55.00
# Unnamed: 5     0.00
# Unnamed: 6     5.21
# dtype: float64
# Mode:
# Year 1997       NaN
# Unnamed: 1    27.00
# Unnamed: 2    24.00
# Unnamed: 3    84.00
# Unnamed: 4    66.00
# Unnamed: 5     0.00
# Unnamed: 6     5.21
# Name: 0, dtype: float64
#
# Sheet: 1998
# ----------------------------------------
# Mean:
# Year 1998           NaN
# Unnamed: 1    31.045479
# Unnamed: 2    19.989589
# Unnamed: 3    70.915068
# Unnamed: 4    51.353425
# Unnamed: 5     1.727945
# Unnamed: 6     5.467397
# dtype: float64
# Median:
# Year 1998       NaN
# Unnamed: 1    30.00
# Unnamed: 2    23.00
# Unnamed: 3    72.00
# Unnamed: 4    49.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Year 1998       NaN
# Unnamed: 1    28.00
# Unnamed: 2    25.00
# Unnamed: 3    92.00
# Unnamed: 4    43.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# Name: 0, dtype: float64
#
# Sheet: 1999
# ----------------------------------------
# Mean:
# Year 1999           NaN
# Unnamed: 1    31.505753
# Unnamed: 2    19.329041
# Unnamed: 3    71.690411
# Unnamed: 4    48.638904
# Unnamed: 5     4.601096
# Unnamed: 6     4.389544
# dtype: float64
# Median:
# Year 1999       NaN
# Unnamed: 1    30.00
# Unnamed: 2    21.00
# Unnamed: 3    77.00
# Unnamed: 4    44.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# dtype: float64
# Mode:
# Year 1999       NaN
# Unnamed: 1    30.00
# Unnamed: 2    24.00
# Unnamed: 3    92.00
# Unnamed: 4    38.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# Name: 0, dtype: float64
#
# Sheet: 2000
# ----------------------------------------
# Mean:
# Year 2000           NaN
# Unnamed: 1    32.433708
# Unnamed: 2    18.389326
# Unnamed: 3    71.668539
# Unnamed: 4    45.311798
# Unnamed: 5     2.165753
# Unnamed: 6     5.380702
# dtype: float64
# Median:
# Year 2000       NaN
# Unnamed: 1    31.00
# Unnamed: 2    18.50
# Unnamed: 3    75.00
# Unnamed: 4    41.50
# Unnamed: 5     0.00
# Unnamed: 6     4.78
# dtype: float64
# Mode:
# Year 2000       NaN
# Unnamed: 1    36.00
# Unnamed: 2    24.00
# Unnamed: 3    92.00
# Unnamed: 4    42.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# Name: 0, dtype: float64
#
# Sheet: 2001
# ----------------------------------------
# Mean:
# Year 2001           NaN
# Unnamed: 1    31.263014
# Unnamed: 2    19.161644
# Unnamed: 3    74.380822
# Unnamed: 4    54.032877
# Unnamed: 5     2.747397
# Unnamed: 6     5.643918
# dtype: float64
# Median:
# Year 2001       NaN
# Unnamed: 1    31.00
# Unnamed: 2    21.00
# Unnamed: 3    78.00
# Unnamed: 4    56.00
# Unnamed: 5     0.00
# Unnamed: 6     4.78
# dtype: float64
# Mode:
# Year 2001       NaN
# Unnamed: 1    30.00
# Unnamed: 2    24.00
# Unnamed: 3    84.00
# Unnamed: 4    61.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# Name: 0, dtype: float64
#
# Sheet: 2002
# ----------------------------------------
# Mean:
# Year 2002           NaN
# Unnamed: 1    31.784110
# Unnamed: 2    19.743014
# Unnamed: 3    74.536986
# Unnamed: 4    52.824658
# Unnamed: 5     3.381096
# Unnamed: 6     5.877890
# dtype: float64
# Median:
# Year 2002       NaN
# Unnamed: 1    31.00
# Unnamed: 2    21.00
# Unnamed: 3    78.00
# Unnamed: 4    53.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Year 2002       NaN
# Unnamed: 1    30.00
# Unnamed: 2    24.00
# Unnamed: 3    80.00
# Unnamed: 4    50.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# Name: 0, dtype: float64
#
# Sheet: 2003
# ----------------------------------------
# Mean:
# Year 2003           NaN
# Unnamed: 1    31.295342
# Unnamed: 2    19.802740
# Unnamed: 3    75.378082
# Unnamed: 4    57.309589
# Unnamed: 5     3.735890
# Unnamed: 6     5.375534
# dtype: float64
# Median:
# Year 2003       NaN
# Unnamed: 1    30.00
# Unnamed: 2    21.00
# Unnamed: 3    82.00
# Unnamed: 4    60.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# dtype: float64
# Mode:
# Year 2003       NaN
# Unnamed: 1    30.00
# Unnamed: 2    25.00
# Unnamed: 3    95.00
# Unnamed: 4    55.00
# Unnamed: 5     0.00
# Unnamed: 6     3.48
# Name: 0, dtype: float64
#
# Sheet: 2004
# ----------------------------------------
# Mean:
# Year 2004           NaN
# Unnamed: 1    31.694536
# Unnamed: 2    19.544262
# Unnamed: 3    76.642077
# Unnamed: 4    57.737705
# Unnamed: 5     3.307104
# Unnamed: 6     5.525902
# dtype: float64
# Median:
# Year 2004       NaN
# Unnamed: 1    31.00
# Unnamed: 2    22.00
# Unnamed: 3    81.00
# Unnamed: 4    58.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Year 2004       NaN
# Unnamed: 1    31.00
# Unnamed: 2    24.00
# Unnamed: 3    88.00
# Unnamed: 4    60.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# Name: 0, dtype: float64
#
# Sheet: 2005
# ----------------------------------------
# Mean:
# Year 2005           NaN
# Unnamed: 1    31.315068
# Unnamed: 2    19.062088
# Unnamed: 3    76.386301
# Unnamed: 4    56.898630
# Unnamed: 5     2.365205
# Unnamed: 6     5.577342
# dtype: float64
# Median:
# Year 2005       NaN
# Unnamed: 1    30.00
# Unnamed: 2    20.00
# Unnamed: 3    83.00
# Unnamed: 4    61.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Year 2005       NaN
# Unnamed: 1    29.00
# Unnamed: 2    25.00
# Unnamed: 3    92.00
# Unnamed: 4    66.00
# Unnamed: 5     0.00
# Unnamed: 6     2.61
# Name: 0, dtype: float64
#
# Sheet: 2006
# ----------------------------------------
# Mean:
# Unnamed: 0    63.849057
# Unnamed: 1    31.265385
# Unnamed: 2    19.930769
# Unnamed: 3    79.711538
# Unnamed: 4    49.629630
# Unnamed: 5    73.720000
# Unnamed: 6    37.784615
# Unnamed: 7     1.519231
# Unnamed: 8     4.899231
# dtype: float64
# Median:
# Unnamed: 0    27.000
# Unnamed: 1    30.100
# Unnamed: 2    21.100
# Unnamed: 3    83.000
# Unnamed: 4    49.000
# Unnamed: 5    71.000
# Unnamed: 6     0.000
# Unnamed: 7     0.000
# Unnamed: 8     3.585
# dtype: float64
# Mode:
# Unnamed: 0     1.00
# Unnamed: 1    26.70
# Unnamed: 2    24.30
# Unnamed: 3    82.00
# Unnamed: 4    32.00
# Unnamed: 5    65.00
# Unnamed: 6     0.00
# Unnamed: 7     0.00
# Unnamed: 8     2.98
# Name: 0, dtype: float64
#
# Sheet: 2007
# ----------------------------------------
# Mean:
# Unnamed: 0    85.178571
# Unnamed: 1    33.544444
# Unnamed: 2    19.585185
# Unnamed: 3    67.107407
# Unnamed: 4    37.722222
# Unnamed: 5    18.177778
# Unnamed: 6     0.851852
# Unnamed: 7     6.910370
# dtype: float64
# Median:
# Unnamed: 0    14.50
# Unnamed: 1    35.80
# Unnamed: 2    18.60
# Unnamed: 3    75.00
# Unnamed: 4    41.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     6.74
# dtype: float64
# Mode:
# Unnamed: 0     1.00
# Unnamed: 1    23.70
# Unnamed: 2    26.40
# Unnamed: 3    81.00
# Unnamed: 4    24.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     8.94
# Name: 0, dtype: float64
#
# Sheet: 2008
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    31.165212
# Year 2008     19.149392
# Unnamed: 3    81.289021
# Unnamed: 4    61.536085
# Unnamed: 5     3.232275
# Unnamed: 6     5.303016
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.00
# Year 2008     20.50
# Unnamed: 3    83.00
# Unnamed: 4    65.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    32.00
# Year 2008     25.00
# Unnamed: 3    88.00
# Unnamed: 4    65.00
# Unnamed: 5     0.00
# Unnamed: 6     4.34
# Name: 0, dtype: float64
#
# Sheet: 2009
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    31.834748
# Year 2009     19.760212
# Unnamed: 3    84.596817
# Unnamed: 4    57.098404
# Unnamed: 5     6.402122
# Unnamed: 6     0.312997
# Unnamed: 7     5.888006
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.00
# Year 2009     20.00
# Unnamed: 3    88.00
# Unnamed: 4    59.50
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     4.34
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    32.00
# Year 2009     24.00
# Unnamed: 3    92.00
# Unnamed: 4    27.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     3.48
# Name: 0, dtype: float64
#
# Sheet: 2010
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    31.850133
# Year 2010     20.589920
# Unnamed: 3    76.377454
# Unnamed: 4    49.952255
# Unnamed: 5     6.335809
# Unnamed: 6     0.254642
# Unnamed: 7     5.742136
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.00
# Year 2010     22.00
# Unnamed: 3    86.00
# Unnamed: 4    55.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     3.91
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    32.00
# Year 2010     25.00
# Unnamed: 3    91.00
# Unnamed: 4    66.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     2.61
# Name: 0, dtype: float64
#
# Sheet: 2011
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    31.432361
# Year 2011     19.368700
# Unnamed: 3    78.466844
# Unnamed: 4    53.938992
# Unnamed: 5     5.162334
# Unnamed: 6     0.307692
# Unnamed: 7     6.051241
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.00
# Year 2011     21.00
# Unnamed: 3    83.00
# Unnamed: 4    59.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     4.34
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    30.00
# Year 2011     25.00
# Unnamed: 3    92.00
# Unnamed: 4    55.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     4.34
# Name: 0, dtype: float64
#
# Sheet: 2012
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    31.973016
# Year 2012     18.923810
# Unnamed: 3    74.978836
# Unnamed: 4    50.455026
# Unnamed: 5     8.150265
# Unnamed: 6     0.349206
# Unnamed: 7     7.525084
# Unnamed: 8     2.292021
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.50
# Year 2012     20.00
# Unnamed: 3    78.00
# Unnamed: 4    54.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     4.35
# Unnamed: 8     1.00
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    39.00
# Year 2012     11.00
# Unnamed: 3    88.00
# Unnamed: 4    65.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     2.61
# Unnamed: 8     1.00
# Name: 0, dtype: float64
#
# Sheet: 2013
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    32.031830
# Year 2013     19.427056
# Unnamed: 3    70.678780
# Unnamed: 4    40.896552
# Unnamed: 5     7.520424
# Unnamed: 6     0.408488
# Unnamed: 7     5.589877
# Unnamed: 8     1.264033
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    31.40
# Year 2013     21.80
# Unnamed: 3    74.00
# Unnamed: 4    38.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     3.48
# Unnamed: 8     1.00
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    29.50
# Year 2013     23.40
# Unnamed: 3    88.00
# Unnamed: 4    66.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     2.61
# Unnamed: 8     0.00
# Name: 0, dtype: float64
#
# Sheet: 2014
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    33.170822
# Year 2014     18.588064
# Unnamed: 3    65.086592
# Unnamed: 4    30.011173
# Unnamed: 5     5.280637
# Unnamed: 6     0.323607
# Unnamed: 7     5.071472
# Unnamed: 8     0.000000
# dtype: float64
# Median:
# Unnamed: 0      NaN
# Unnamed: 1    32.90
# Year 2014     19.60
# Unnamed: 3    66.00
# Unnamed: 4    24.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     3.91
# Unnamed: 8     0.00
# dtype: float64
# Mode:
# Unnamed: 0      NaN
# Unnamed: 1    31.00
# Year 2014     21.00
# Unnamed: 3    88.00
# Unnamed: 4    11.00
# Unnamed: 5     0.00
# Unnamed: 6     0.00
# Unnamed: 7     1.74
# Unnamed: 8     0.00
# Name: 0, dtype: float64
#
# Sheet: 2015
# ----------------------------------------
# Mean:
# Unnamed: 0           NaN
# Unnamed: 1     31.931804
# Year 2015      19.867451
# Unnamed: 3     76.127962
# Unnamed: 4     43.142180
# Unnamed: 5      4.206275
# Unnamed: 6      0.682353
# Unnamed: 7      1.985658
# Unnamed: 8      0.000000
# Unnamed: 9     48.618182
# Unnamed: 10    31.708333
# Unnamed: 11          NaN
# Unnamed: 12          NaN
# Unnamed: 13          NaN
# Unnamed: 14          NaN
# dtype: float64
# Median:
# Unnamed: 0       NaN
# Unnamed: 1     32.00
# Year 2015      22.80
# Unnamed: 3     85.00
# Unnamed: 4     31.00
# Unnamed: 5      0.00
# Unnamed: 6      0.00
# Unnamed: 7      1.74
# Unnamed: 8      0.00
# Unnamed: 9     12.40
# Unnamed: 10     2.50
# Unnamed: 11      NaN
# Unnamed: 12      NaN
# Unnamed: 13      NaN
# Unnamed: 14      NaN
# dtype: float64
# Mode:
# Unnamed: 0       NaN
# Unnamed: 1     28.40
# Year 2015      24.30
# Unnamed: 3     99.00
# Unnamed: 4     99.00
# Unnamed: 5      0.00
# Unnamed: 6      0.00
# Unnamed: 7      1.74
# Unnamed: 8      0.00
# Unnamed: 9      0.00
# Unnamed: 10     0.00
# Unnamed: 11      NaN
# Unnamed: 12      NaN
# Unnamed: 13      NaN
# Unnamed: 14      NaN
# Name: 0, dtype: float64
#
# Sheet: 2016
# ----------------------------------------
# Mean:
# Unnamed: 0          NaN
# Unnamed: 1    32.705761
# Year 2016     19.470899
# Unnamed: 3    12.461538
# Unnamed: 4    10.307692
# Unnamed: 5     8.118519
# Unnamed: 6     0.323607
# Unnamed: 7     0.379949
# Unnamed: 8     0.000000
# dtype: float64
# Median:
# Unnamed: 0          NaN
# Unnamed: 1    31.666667
# Year 2016     21.666667
# Unnamed: 3     0.000000
# Unnamed: 4     0.000000
# Unnamed: 5     0.000000
# Unnamed: 6     0.000000
# Unnamed: 7     0.000000
# Unnamed: 8     0.000000
# dtype: float64
# Mode:
# Unnamed: 0          NaN
# Unnamed: 1    29.444444
# Year 2016     23.333333
# Unnamed: 3     0.000000
# Unnamed: 4     0.000000
# Unnamed: 5     0.000000
# Unnamed: 6     0.000000
# Unnamed: 7     0.000000
# Unnamed: 8     0.000000
# Name: 0, dtype: float64
#
# Sheet: 2017
# ----------------------------------------
# Mean:
# Zonal Agricultural Research Station, Powarkheda 2017          NaN
# Unnamed: 1                                              33.620424
# Unnamed: 2                                              20.337135
# Unnamed: 3                                              68.481440
# Unnamed: 4                                              47.473514
# Unnamed: 5                                               5.707692
# Unnamed: 6                                               0.501326
# Unnamed: 7                                               0.000000
# Unnamed: 8                                               0.000000
# dtype: float64
# Median:
# Zonal Agricultural Research Station, Powarkheda 2017          NaN
# Unnamed: 1                                              32.500000
# Unnamed: 2                                              22.400000
# Unnamed: 3                                              71.460593
# Unnamed: 4                                              45.022121
# Unnamed: 5                                               0.000000
# Unnamed: 6                                               0.000000
# Unnamed: 7                                               0.000000
# Unnamed: 8                                               0.000000
# dtype: float64
# Mode:
# Zonal Agricultural Research Station, Powarkheda 2017           NaN
# Unnamed: 1                                               31.200000
# Unnamed: 2                                               25.000000
# Unnamed: 3                                               92.027757
# Unnamed: 4                                              100.000000
# Unnamed: 5                                                0.000000
# Unnamed: 6                                                0.000000
# Unnamed: 7                                                0.000000
# Unnamed: 8                                                0.000000
# Name: 0, dtype: float64
#
# Sheet: 2018
# ----------------------------------------
# Mean:
# Standard Meteorological Week wise Weather data           NaN
# Unnamed: 1                                         33.034748
# Unnamed: 2                                         19.628117
# Unnamed: 3                                         68.481440
# Unnamed: 4                                         47.473514
# Unnamed: 5                                          6.685714
# Unnamed: 6                                          1.710843
# Unnamed: 7                                          1.970497
# Unnamed: 8                                          0.000000
# Unnamed: 9                                               NaN
# Unnamed: 10                                       141.327273
# Unnamed: 11                                         6.454545
# Unnamed: 12                                              NaN
# Unnamed: 13                                              NaN
# Unnamed: 14                                              NaN
# Unnamed: 15                                              NaN
# Unnamed: 16                                              NaN
# Unnamed: 17                                              NaN
# Unnamed: 18                                              NaN
# Unnamed: 19                                              NaN
# Unnamed: 20                                              NaN
# Unnamed: 21                                              NaN
# Unnamed: 22                                              NaN
# dtype: float64
# Median:
# Standard Meteorological Week wise Weather data          NaN
# Unnamed: 1                                        32.400000
# Unnamed: 2                                        20.500000
# Unnamed: 3                                        71.460593
# Unnamed: 4                                        45.022121
# Unnamed: 5                                         0.000000
# Unnamed: 6                                         1.000000
# Unnamed: 7                                         0.000000
# Unnamed: 8                                         0.000000
# Unnamed: 9                                              NaN
# Unnamed: 10                                        5.600000
# Unnamed: 11                                        1.000000
# Unnamed: 12                                             NaN
# Unnamed: 13                                             NaN
# Unnamed: 14                                             NaN
# Unnamed: 15                                             NaN
# Unnamed: 16                                             NaN
# Unnamed: 17                                             NaN
# Unnamed: 18                                             NaN
# Unnamed: 19                                             NaN
# Unnamed: 20                                             NaN
# Unnamed: 21                                             NaN
# Unnamed: 22                                             NaN
# dtype: float64
# Mode:
# Standard Meteorological Week wise Weather data           NaN
# Unnamed: 1                                         35.000000
# Unnamed: 2                                         23.500000
# Unnamed: 3                                         92.027757
# Unnamed: 4                                        100.000000
# Unnamed: 5                                          0.000000
# Unnamed: 6                                          1.000000
# Unnamed: 7                                          0.000000
# Unnamed: 8                                          0.000000
# Unnamed: 9                                               NaN
# Unnamed: 10                                         0.000000
# Unnamed: 11                                         0.000000
# Unnamed: 12                                              NaN
# Unnamed: 13                                              NaN
# Unnamed: 14                                              NaN
# Unnamed: 15                                              NaN
# Unnamed: 16                                              NaN
# Unnamed: 17                                              NaN
# Unnamed: 18                                              NaN
# Unnamed: 19                                              NaN
# Unnamed: 20                                              NaN
# Unnamed: 21                                              NaN
# Unnamed: 22                                              NaN
# Name: 0, dtype: float64
#
# Sheet: 2019
# ----------------------------------------
# Mean:
# Standard Meteorological Week wise Weather data          NaN
# Unnamed: 1                                        31.684615
# Unnamed: 2                                        18.709549
# Unnamed: 3                                        58.136361
# Unnamed: 4                                        39.011974
# Unnamed: 5                                        15.873043
# Unnamed: 6                                         0.753623
# Unnamed: 7                                         2.675774
# Unnamed: 8                                              NaN
# Unnamed: 9                                              NaN
# Unnamed: 10                                             NaN
# Unnamed: 11                                             NaN
# Unnamed: 12                                             NaN
# dtype: float64
# Median:
# Standard Meteorological Week wise Weather data          NaN
# Unnamed: 1                                        29.500000
# Unnamed: 2                                        20.500000
# Unnamed: 3                                        63.211510
# Unnamed: 4                                        41.750012
# Unnamed: 5                                         0.000000
# Unnamed: 6                                         0.000000
# Unnamed: 7                                         3.472000
# Unnamed: 8                                              NaN
# Unnamed: 9                                              NaN
# Unnamed: 10                                             NaN
# Unnamed: 11                                             NaN
# Unnamed: 12                                             NaN
# dtype: float64
# Mode:
# Standard Meteorological Week wise Weather data       NaN
# Unnamed: 1                                        29.000
# Unnamed: 2                                        24.000
# Unnamed: 3                                         0.000
# Unnamed: 4                                         0.000
# Unnamed: 5                                         0.000
# Unnamed: 6                                         0.000
# Unnamed: 7                                         3.472
# Unnamed: 8                                           NaN
# Unnamed: 9                                           NaN
# Unnamed: 10                                          NaN
# Unnamed: 11                                          NaN
# Unnamed: 12                                          NaN
# Name: 0, dtype: float64
#
# Sheet: 2020
# ----------------------------------------
# Mean:
# Standard Meteorological Week wise Weather data            NaN
# Unnamed: 1                                          28.029864
# Unnamed: 2                                          14.685065
# Unnamed: 3                                           0.000000
# Unnamed: 4                                           0.000000
# Unnamed: 5                                           0.264935
# Unnamed: 6                                           0.103896
# Unnamed: 7                                           1.833917
# Unnamed: 8                                                NaN
# Unnamed: 9                                           0.000000
# Unnamed: 10                                          0.000000
# Unnamed: 11                                         22.253949
# Unnamed: 12                                               NaN
# Unnamed: 13                                               NaN
# Unnamed: 14                                         22.600000
# Unnamed: 15                                               NaN
# Unnamed: 16                                               NaN
# Unnamed: 17                                       1130.000000
# Unnamed: 18                                               NaN
# Unnamed: 19                                       1320.000000
# Unnamed: 20                                       -435.814815
# Unnamed: 21                                               NaN
# dtype: float64
# Median:
# Standard Meteorological Week wise Weather data            NaN
# Unnamed: 1                                          28.000000
# Unnamed: 2                                          13.000000
# Unnamed: 3                                           0.000000
# Unnamed: 4                                           0.000000
# Unnamed: 5                                           0.000000
# Unnamed: 6                                           0.000000
# Unnamed: 7                                           0.000000
# Unnamed: 8                                                NaN
# Unnamed: 9                                           0.000000
# Unnamed: 10                                          0.000000
# Unnamed: 11                                         22.263792
# Unnamed: 12                                               NaN
# Unnamed: 13                                               NaN
# Unnamed: 14                                         22.600000
# Unnamed: 15                                               NaN
# Unnamed: 16                                               NaN
# Unnamed: 17                                       1130.000000
# Unnamed: 18                                               NaN
# Unnamed: 19                                       1320.000000
# Unnamed: 20                                          0.000000
# Unnamed: 21                                               NaN
# dtype: float64
# Mode:
# Standard Meteorological Week wise Weather data            NaN
# Unnamed: 1                                          28.000000
# Unnamed: 2                                           0.000000
# Unnamed: 3                                           0.000000
# Unnamed: 4                                           0.000000
# Unnamed: 5                                           0.000000
# Unnamed: 6                                           0.000000
# Unnamed: 7                                           0.000000
# Unnamed: 8                                                NaN
# Unnamed: 9                                           0.000000
# Unnamed: 10                                          0.000000
# Unnamed: 11                                         44.488213
# Unnamed: 12                                               NaN
# Unnamed: 13                                               NaN
# Unnamed: 14                                          0.000000
# Unnamed: 15                                               NaN
# Unnamed: 16                                               NaN
# Unnamed: 17                                       1130.000000
# Unnamed: 18                                               NaN
# Unnamed: 19                                       1320.000000
# Unnamed: 20                                      -1320.000000
# Unnamed: 21                                               NaN
# Name: 0, dtype: float64

# %% [markdown]
# # Total Number of Rows #

# %%
for sheet in sheet_names:
    df = pd.read_excel( "Weatherdata1996to2020.xls", sheet_name=sheet) 
    print(f"Sheet: {sheet} -> Rows: {df.shape[0]}")
# Out:
# Sheet: 1996 -> Rows: 368
# Sheet: 1997 -> Rows: 368
# Sheet: 1998 -> Rows: 368
# Sheet: 1999 -> Rows: 367
# Sheet: 2000 -> Rows: 368
# Sheet: 2001 -> Rows: 368
# Sheet: 2002 -> Rows: 368
# Sheet: 2003 -> Rows: 368
# Sheet: 2004 -> Rows: 368
# Sheet: 2005 -> Rows: 368
# Sheet: 2006 -> Rows: 57
# Sheet: 2007 -> Rows: 30
# Sheet: 2008 -> Rows: 380
# Sheet: 2009 -> Rows: 379
# Sheet: 2010 -> Rows: 379
# Sheet: 2011 -> Rows: 379
# Sheet: 2012 -> Rows: 380
# Sheet: 2013 -> Rows: 379
# Sheet: 2014 -> Rows: 379
# Sheet: 2015 -> Rows: 379
# Sheet: 2016 -> Rows: 380
# Sheet: 2017 -> Rows: 379
# Sheet: 2018 -> Rows: 384
# Sheet: 2019 -> Rows: 380
# Sheet: 2020 -> Rows: 381

# %% [markdown]
# ## Total rows in xls file ( including all tabs ) ##

# %%
total_rows = 0
for sheet in sheet_names:
    sheet_df = pd.read_excel("Weatherdata1996to2020.xls", sheet_name=sheet)
    sheet_row_count = sheet_df.shape[0]
    total_rows += sheet_row_count
print(f"\n Total Rows in Entire File: {total_rows}")
# Out:
#  Total Rows in Entire File: 8704

# %% [markdown]
# ## Size of data before Preprocessing ##

# %%
size_bytes = os.path.getsize("C:\\Users\\Nakesh\\Desktop\\weather data\\jupyter-notebook-weather-project\\Weatherdata1996to2020.xls") 
size_kb = size_bytes / 1024 
print(f"The size of Weatherdata1996to2020.xls is :{size_kb}")
# Out:
# The size of Weatherdata1996to2020.xls is :1022.0

# %% [markdown]
# ## DATA PROCESSING ##

# %%
# Removing rows with values 20,11,NaN in column "Rainy Days" 
weather = weather[~weather['Rainy Days '].isin([ 20 , 11 ])]
weather = weather[~weather['Rainy Days '].isna()] 

# Removing Rows with values "Average" in column "Date"
weather = weather[~weather['Date'].isin(['Average'])]

# Removing rows with blank spaces in column "Date"
weather = weather[~weather['Date'].isin([' '])]

# weather['Date'].value_counts(dropna=False)
# Removing Duplicate rows 
weather = weather.drop_duplicates(subset='Date')

weather['Date'].value_counts(dropna=False)

weather['Rainy Days '].unique()
weather['Rainy Days '].value_counts()

# weather['Rain'].unique()
# Out:
# Rainy Days
# 0.0    2832
# 1.0     666
# Name: count, dtype: int64

# %%
# weather['cloud cover'].value_counts(dropna=False)
# cloud cover
# NaN    7326
# 1.0     162
# 0.0     141
# 4.0      43
# 2.0      42
# 8.0      38
# 3.0      19
# 7.0      16
# 5.0      12
# 6.0       7
# Name: count, dtype: int64
# Removing the Cloud cover column bacause it has high nummber of Null values 
weather = weather.drop('cloud cover' , axis=1)

# %%
weather
# Out:
#           Date  Max.  Min. Morn  Eve Rain  Rainy Days     PE  Year
# 0     01.01.20  21.0  13.5  NaN  NaN  0.0          0.0  0.43  1996
# 1      2.01.20  22.5  13.5  NaN  NaN  2.0          1.0  0.43  1996
# 2      3.01.20  21.5  15.5  NaN  NaN  0.0          0.0  0.43  1996
# 3      4.01.20  19.0  11.5  NaN  NaN  0.0          0.0  0.87  1996
# 4      5.01.20  23.0   8.0  NaN  NaN  0.0          0.0  1.74  1996
# ...        ...   ...   ...  ...  ...  ...          ...   ...   ...
# 7662  27.12.19  20.5   8.0  NaN  NaN  0.0          0.0  3.04  2019
# 7663  28.12.19  21.5   6.5  NaN  NaN  0.0          0.0  3.47  2019
# 7664  29.12.19  22.5   5.5  NaN  NaN  0.0          0.0  3.47  2019
# 7665  30.12.19  22.0   6.0  NaN  NaN  0.0          0.0  3.04  2019
# 7666  31.12.19  17.5   6.5  NaN  NaN  1.8          1.0   2.6  2019
#
# [3498 rows x 9 columns]

# %%
# converting non-numaric values into numeric 
weather['Max.'] = pd.to_numeric(weather['Max.'], errors='coerce')
weather['Min.'] = pd.to_numeric(weather['Min.'], errors='coerce')
weather['Morn'] = pd.to_numeric(weather['Morn'], errors='coerce')
weather['Eve'] = pd.to_numeric(weather['Eve'], errors='coerce')
weather['PE'] = pd.to_numeric(weather['PE'], errors='coerce')
weather['Date'] = pd.to_numeric(weather['Date'], errors='coerce')
weather['Rainy Days '] = pd.to_numeric(weather['Rainy Days '], errors='coerce')
weather['Rain'] = pd.to_numeric(weather['Rain'], errors='coerce')

# %%
# Filling Meadian In place of NaN values 

# calculating median for each column 
median_Max = weather['Max.'].median()
median_Min = weather['Min.'].median()
median_Morn = weather['Morn'].median()
median_Eve = weather['Eve'].median()
median_PE = weather['PE'].median()


# replace Null value with median 
weather['Max.'] = weather['Max.'].fillna(median_Max)
weather['Min.'] = weather['Min.'].fillna(median_Min)
weather['Morn'] = weather['Morn'].fillna(median_Morn)
weather['Eve'] = weather['Eve'].fillna(median_Eve)
weather['PE'] = weather['PE'].fillna(median_PE)

# %%
# print(weather['Eve'].unique())
# print(weather['Morn'].unique())
# print(weather['Min.'].unique())

# %%
weather
# Out:
#       Date  Max.  Min.  Morn   Eve  Rain  Rainy Days     PE  Year
# 0      NaN  21.0  13.5  78.0  49.0   0.0          0.0  0.43  1996
# 1      NaN  22.5  13.5  78.0  49.0   2.0          1.0  0.43  1996
# 2      NaN  21.5  15.5  78.0  49.0   0.0          0.0  0.43  1996
# 3      NaN  19.0  11.5  78.0  49.0   0.0          0.0  0.87  1996
# 4      NaN  23.0   8.0  78.0  49.0   0.0          0.0  1.74  1996
# ...    ...   ...   ...   ...   ...   ...          ...   ...   ...
# 7662   NaN  20.5   8.0  78.0  49.0   0.0          0.0  3.04  2019
# 7663   NaN  21.5   6.5  78.0  49.0   0.0          0.0  3.47  2019
# 7664   NaN  22.5   5.5  78.0  49.0   0.0          0.0  3.47  2019
# 7665   NaN  22.0   6.0  78.0  49.0   0.0          0.0  3.04  2019
# 7666   NaN  17.5   6.5  78.0  49.0   1.8          1.0  2.60  2019
#
# [3498 rows x 9 columns]

# %%
# cheking for any Null values 
print(weather.isnull().sum())
# Out:
# Date           3498
# Max.              0
# Min.              0
# Morn              0
# Eve               0
# Rain              0
# Rainy Days        0
# PE                0
# Year              0
# dtype: int64

# %%
# exporting the weather DataFrame to CSV format 
weather.to_csv('weather_clean_dataSet.csv', index=False)
type(weather['Date'])
# Out:
# pandas.core.series.Series

# %%
# Plotting 

sns.pairplot(weather)

# %%
sns.heatmap(weather.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Columns")
plt.show()

# %%
print(weather.dtypes)
# Out:
# Date           float64
# Max.           float64
# Min.           float64
# Morn           float64
# Eve            float64
# Rain           float64
# Rainy Days     float64
# PE             float64
# Year             int64
# dtype: object

# %%
# # Splitting data set for Training & testing 
weather = weather.drop('Year', axis=1)
weather = weather.drop('Date', axis=1)

train = weather[ : 3400]
test = weather[ 3400 : ]

# %% [markdown]
# ## Analysis After data Processing ##

# %%
# Top 5 rows 
print(weather.head())

# columns & Their types
print(weather.info())

# Missing values 
print(weather.isnull().sum())

# Summary statistics
print(weather.describe())
# Out:
#    Max.  Min.  Morn   Eve  Rain  Rainy Days     PE
# 0  21.0  13.5  78.0  49.0   0.0          0.0  0.43
# 1  22.5  13.5  78.0  49.0   2.0          1.0  0.43
# 2  21.5  15.5  78.0  49.0   0.0          0.0  0.43
# 3  19.0  11.5  78.0  49.0   0.0          0.0  0.87
# 4  23.0   8.0  78.0  49.0   0.0          0.0  1.74
# <class 'pandas.core.frame.DataFrame'>
# Index: 3498 entries, 0 to 7666
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Max.         3498 non-null   float64
#  1   Min.         3498 non-null   float64
#  2   Morn         3498 non-null   float64
#  3   Eve          3498 non-null   float64
#  4   Rain         3498 non-null   float64
#  5   Rainy Days   3498 non-null   float64
#  6   PE           3498 non-null   float64
# dtypes: float64(7)
# memory usage: 218.6 KB
# None
# Max.           0
# Min.           0
# Morn           0
# Eve            0
# Rain           0
# Rainy Days     0
# PE             0
# dtype: int64
#               Max.         Min.         Morn          Eve         Rain  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     31.915923    19.568096    74.827959    47.861063     3.521870
# std       5.955919     6.796050    17.287809    20.859584    13.981569
# min       3.000000     1.600000    17.000000     5.000000     0.000000
# 25%      28.000000    14.200000    67.000000    32.000000     0.000000
# 50%      31.000000    21.000000    78.000000    49.000000     0.000000
# 75%      36.000000    24.400000    88.000000    62.000000     0.000000
# max      46.670000   123.500000   100.000000   320.000000   193.600000
#
#        Rainy Days            PE
# count  3498.000000  3498.000000
# mean      0.190395     4.905666
# std       0.392668     6.698402
# min       0.000000   -52.080000
# 25%       0.000000     3.040000
# 50%       0.000000     3.910000
# 75%       0.000000     5.220000
# max       1.000000   168.430000

# %% [markdown]
# ## Total Number Of rows in data after Preprocessing ##

# %%
rows_length = len(weather)
print(f"Total Number of rows after Preprocessing : {rows_length}")
# Out:
# Total Number of rows after Preprocessing : 3498

# %% [markdown]
# ## Size of weather file after preprocessing ##

# %%
total_size_bytes = weather.memory_usage(deep=True).sum()
total_size_mb = total_size_bytes / (1024 * 1024)
print(f"Total DataFrame size: {total_size_mb:.2f} MB")
# Out:
# Total DataFrame size: 0.21 MB
